# %% [markdown]
# ### ANSWER TO QUESTION 1:

# %% [markdown]
# #### . What is Flask Framework? What are the advantages of Flask Framework

# %% [markdown]
# ##### Flask is a micro web framework for Python that allows you to build web applications and services. It is:
#
# ##### - Lightweight: Flask is a minimalist framework that doesn't include many features out of the box, making it flexible and easy to learn.
# ##### - Modular: Flask is designed to be modular, allowing you to build applications in a modular fashion.
# ##### - Flexible: Flask doesn't enforce a specific way of building applications, giving you the freedom to choose your own tools and libraries.

# %% [markdown]
# ### ANSWER TO QUESTION 2:

# %% [markdown]
# #### . Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask
app=Flask(__name__)
@app.route('/')
def question2():
    return "hello world"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.34:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Jul/2024 15:31:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2024 15:31:28] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from IPython.display import Image

Image(filename='pwskills4.jpg')

# %% [markdown]
# ### ANSWER TO QUESTION 3:

# %% [markdown]
# #### What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# ##### App routing in Flask refers to the process of mapping URLs to specific functions or views in your application. It's a way to associate a URL with a particular resource or action.
#
# ##### In Flask, you use the @app.route() decorator to define routes. For example:
#
# @app.route('/')
# def index():
#     return 'Welcome to my app!'
#
# ##### This code defines a route for the root URL ('/') and associates it with the index() function.
#
# ##### We use app routes for several reasons:
#
# ##### 1. URL mapping: Routes allow you to map user-friendly URLs to specific functions or views, making it easier for users to access your application's resources.
# ##### 2. Request handling: Routes help Flask handle incoming requests and direct them to the appropriate functions or views for processing.
# ##### 3. Application structure: Routes help organize your application's logic and structure, making it easier to maintain and extend.
# ##### 4. Flexibility: Routes enable you to define custom URLs and associate them with specific actions or resources, giving you flexibility in designing your application's API

# %% [markdown]
# ### ANSWER TO QUESTION 4:

# %% [markdown]
# ####   Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# ####   route to show the following details:
# #### Company Name: ABC Corporation
# #### Location: India
# #### Contact Detail: 999-999-9999
# #### Attach the screenshot of the output in Jupyter Notebook

# %%
from flask import Flask
app=Flask(__name__)
@app.route("/welcome")
def welcome():
    return "Welcome to ABC Corporation"

@app.route("/")
def details():
    return "Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.34:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Jul/2024 15:52:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2024 15:52:40] "GET /welcome HTTP/1.1" 200 -
# 192.168.1.34 - - [13/Jul/2024 15:53:32] "GET / HTTP/1.1" 200 -
# 192.168.1.34 - - [13/Jul/2024 15:53:32] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jul/2024 15:53:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2024 15:54:09] "GET /details HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jul/2024 15:54:41] "GET / HTTP/1.1" 200 -

# %%
from IPython.display import Image

Image(filename='pwskills5.jpg')

# %%
from IPython.display import Image

Image(filename='pwskills6.jpg')

# %% [markdown]
# ### ANSWER TO QUESTION 5:

# %% [markdown]
# ####  What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function

# %%
###In Flask, the url_for() function is used for URL building. It generates a URL to a specific function or endpoint in your application.
from flask import Flask, redirect, url_for
app = Flask(__name__)
@app.route('/')
def home():
    return 'Home Page'

@app.route('/welcome')
def welcome():
    return 'Welcome Page'

@app.route('/redirect')
def redirect_example():
    return redirect(url_for('welcome'))

if __name__ == '__main__':
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.34:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Jul/2024 16:05:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2024 16:06:00] "GET /redirect HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jul/2024 16:06:00] "GET /welcome HTTP/1.1" 200 -
